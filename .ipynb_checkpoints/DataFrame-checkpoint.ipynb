# %%
import pandas as pd

# %%
EXcel = "C://Users/Dell\Downloads/Tentative.xlsx"
df = pd.read_excel(EXcel)
df.head()
# Out:
#     Course ID                          Discipline  \
# 0  noc23-ae08  Aerospace / Mechanical Engineering
# 1  noc23-ae09               Aerospace Engineering
# 2  noc23-ae10               Aerospace Engineering
# 3  noc23-ae11               Aerospace engineering
# 4  noc23-ae12               Aerospace Engineering
#
#                                      Course Name  \
# 0               Elements Of Mechanical Vibration
# 1                 Aircraft Stability And Control
# 2           Introduction To Airplane Performance
# 3        Introduction To Airbreathing Propulsion
# 4  Design Of Fixed Wing Unmanned Aerial Vehicles
#
#                              SME Name Institute \nCo-ordinating Institute  \
# 0                Prof. Ashish K Darpe      IITD                      IITD
# 1                     Prof. A.K.Ghosh      IITK                      IITK
# 2  Prof. A K Ghosh\nProf Deepu Philip      IITK                      IITK
# ...
